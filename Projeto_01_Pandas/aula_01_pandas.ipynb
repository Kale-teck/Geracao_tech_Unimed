# %%
#importando a biblioteca Pandas
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 2
#       1 #importando a biblioteca Pandas
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dataframe = pd.read_csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 dataframe = pd.read_csv
#
# NameError: name 'pd' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/PANDAS/recomendacao.csv", error_bad_lines=False, sep=';')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#visualizando as 5 primeiras linhas
df.head()
# Out:
#    codigo_ocorrencia4          recomendacao_numero  \
# 0               45331       A-582/CENIPA/2014 - 01
# 1               45331       A-582/CENIPA/2014 - 02
# 2               45331       A-582/CENIPA/2014 - 03
# 3               45392  A-032/CENIPA/2014 - RSV 001
# 4               45392  A-032/CENIPA/2014 - RSV 002
#
#   recomendacao_dia_assinatura recomendacao_dia_encaminhamento  \
# 0                  2016-07-29                      2016-08-25
# 1                  2016-07-29                      2016-08-25
# 2                  2016-07-29                      2016-08-25
# 3                  2014-04-07                      2015-04-14
# 4                  2014-04-07                      2015-04-14
#
#   recomendacao_dia_feedback  \
# 0                2016-12-20
# 1                2016-12-20
# 2                2019-09-16
# 3                2015-08-21
# 4                2015-08-17
#
#                                recomendacao_conteudo  \
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia4          recomendacao_numero  \
# 0               45331       A-582/CENIPA/2014 - 01
# 1               45331       A-582/CENIPA/2014 - 02
# 2               45331       A-582/CENIPA/2014 - 03
# 3               45392  A-032/CENIPA/2014 - RSV 001
# 4               45392  A-032/CENIPA/2014 - RSV 002
#
#   recomendacao_dia_assinatura recomendacao_dia_encaminhamento  \
# 0                  2016-07-29                      2016-08-25
# 1                  2016-07-29                      2016-08-25
# 2                  2016-07-29                      2016-08-25
# 3                  2014-04-07                      2015-04-14
# 4                  2014-04-07                      2015-04-14
#
#   recomendacao_dia_feedback  \
# 0                2016-12-20
# 1                2016-12-20
# 2                2019-09-16
# 3                2015-08-21
# 4                2015-08-17
#
#                                recomendacao_conteudo  \
# ...

# %%
df.rename(columns={'recomendacao_dia_assinatura':'assinatura', 'recomendacao_dia_encaminhamento':'encaminhamento'})
# Out:
#       codigo_ocorrencia4          recomendacao_numero  assinatura  \
# 0                  45331       A-582/CENIPA/2014 - 01  2016-07-29
# 1                  45331       A-582/CENIPA/2014 - 02  2016-07-29
# 2                  45331       A-582/CENIPA/2014 - 03  2016-07-29
# 3                  45392  A-032/CENIPA/2014 - RSV 001  2014-04-07
# 4                  45392  A-032/CENIPA/2014 - RSV 002  2014-04-07
# ...                  ...                          ...         ...
# 1326               79713       A-146/CENIPA/2020 - 03  2021-07-08
# 1327               79748       A-156/CENIPA/2020 - 01  2022-04-12
# 1328               80073       A-063/CENIPA/2021 - 01  2021-11-12
# 1329               80073       A-063/CENIPA/2021 - 02  2021-11-12
# 1330               80258       A-137/CENIPA/2019 - 01  2021-11-16
#
#      encaminhamento recomendacao_dia_feedback  \
# 0        2016-08-25                2016-12-20
# 1        2016-08-25                2016-12-20
# ...

# %%
df.head()
# Out:
#    codigo_ocorrencia4          recomendacao_numero  \
# 0               45331       A-582/CENIPA/2014 - 01
# 1               45331       A-582/CENIPA/2014 - 02
# 2               45331       A-582/CENIPA/2014 - 03
# 3               45392  A-032/CENIPA/2014 - RSV 001
# 4               45392  A-032/CENIPA/2014 - RSV 002
#
#   recomendacao_dia_assinatura recomendacao_dia_encaminhamento  \
# 0                  2016-07-29                      2016-08-25
# 1                  2016-07-29                      2016-08-25
# 2                  2016-07-29                      2016-08-25
# 3                  2014-04-07                      2015-04-14
# 4                  2014-04-07                      2015-04-14
#
#   recomendacao_dia_feedback  \
# 0                2016-12-20
# 1                2016-12-20
# 2                2019-09-16
# 3                2015-08-21
# 4                2015-08-17
#
#                                recomendacao_conteudo  \
# ...

# %%
df = df.rename(columns={'codigo_ocorrencia4':'codigo', 'recomendacao_dia_assinatura':'assinatura', 'recomendacao_dia_encaminhamento':'encaminhamento', 'recomendacao_dia_feedback':'feedback', 'recomendacao_destinatario_sigla':'sigla'})

# %%
df.head(10)
# Out:
#    codigo          recomendacao_numero  assinatura encaminhamento    feedback  \
# 0   45331       A-582/CENIPA/2014 - 01  2016-07-29     2016-08-25  2016-12-20
# 1   45331       A-582/CENIPA/2014 - 02  2016-07-29     2016-08-25  2016-12-20
# 2   45331       A-582/CENIPA/2014 - 03  2016-07-29     2016-08-25  2019-09-16
# 3   45392  A-032/CENIPA/2014 - RSV 001  2014-04-07     2015-04-14  2015-08-21
# 4   45392  A-032/CENIPA/2014 - RSV 002  2014-04-07     2015-04-14  2015-08-17
# 5   45397      IG-536/CENIPA/2014 - 01  2016-04-15     2016-05-17  2017-02-21
# 6   45397      IG-536/CENIPA/2014 - 02  2016-04-15     2016-05-17  2017-02-24
# 7   45400      IG-544/CENIPA/2015 - 01  2017-03-31     2017-03-31  2017-08-08
# 8   45400      IG-544/CENIPA/2015 - 02  2017-03-31     2017-03-31  2017-08-08
# 9   45400      IG-544/CENIPA/2015 - 03  2017-03-31     2017-03-31  2017-08-08
#
#                                recomendacao_conteudo  \
# 0  Atuar junto às empresas que operam segundo o R...
# ...

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0e566b70f572> in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (1331, 9)

# %%
df.columns
# Out:
# Index(['codigo', 'recomendacao_numero', 'assinatura', 'encaminhamento',
#        'feedback', 'recomendacao_conteudo', 'recomendacao_status', 'sigla',
#        'recomendacao_destinatario'],
#       dtype='object')

# %%
df.dtypes
# Out:
# codigo                        int64
# recomendacao_numero          object
# assinatura                   object
# encaminhamento               object
# feedback                     object
# recomendacao_conteudo        object
# recomendacao_status          object
# sigla                        object
# recomendacao_destinatario    object
# dtype: object

# %%
#object equivale a string

# %%
df.tail()
# Out:
#       codigo     recomendacao_numero  assinatura encaminhamento    feedback  \
# 1326   79713  A-146/CENIPA/2020 - 03  2021-07-08     2021-07-26         NaN
# 1327   79748  A-156/CENIPA/2020 - 01  2022-04-12     2022-04-19         NaN
# 1328   80073  A-063/CENIPA/2021 - 01  2021-11-12     2021-11-19  2021-12-02
# 1329   80073  A-063/CENIPA/2021 - 02  2021-11-12     2021-11-19  2021-12-02
# 1330   80258  A-137/CENIPA/2019 - 01  2021-11-16     2021-12-23  2022-01-26
#
#                                   recomendacao_conteudo  recomendacao_status  \
# 1326  Divulgar os ensinamentos colhidos na presente ...  AGUARDANDO RESPOSTA
# 1327  Reforçar a atuação junto à Mercaer Aviação Agr...  AGUARDANDO RESPOSTA
# 1328  Divulgar os ensinamentos colhidos nesta invest...             CUMPRIDA
# 1329  Divulgar os ensinamentos colhidos nesta invest...             CUMPRIDA
# 1330  Atuar junto ao operador do Aeródromo de Tangar...             CUMPRIDA
#
#      sigla          recomendacao_destinatario
# ...

# %%
df.describe()
# Out:
#              codigo
# count   1331.000000
# mean   62152.878287
# std    13050.010825
# min    45331.000000
# 25%    50314.000000
# 50%    60689.000000
# 75%    77768.000000
# max    80258.000000

# %%
df['sigla'].unique()
# Out:
# array(['ANAC', 'DECEA', 'LYCOMING', 'SSP-GO', 'CNP', 'ABAG', 'APPA',
#        'FAA', 'SINDAG', 'SAC', 'ANP', 'DINACIA', 'DIRSA', 'AEROPREST',
#        'PETROBRÁS', 'MB', 'COMGAP', 'GABAER', 'COMPREP', 'BEA', 'TSB'],
#       dtype=object)

# %%
petrobras = df.loc[df['sigla']=='PETROBRÁS']
petrobras.head()
# Out:
#      codigo        recomendacao_numero  assinatura encaminhamento feedback  \
# 470   52699  I - 215/CENIPA/2015 – 005  2015-03-06     2015-03-20      NaN
#
#                                  recomendacao_conteudo  recomendacao_status  \
# 470  Incrementar a fiscalização na adequação dos re...  AGUARDANDO RESPOSTA
#
#          sigla       recomendacao_destinatario
# 470  PETROBRÁS  EMPRESA BRASILEIRA DE PETRÓLEO

# %%
anac = df.loc[df['sigla']=='ANAC']
anac.head()
# Out:
#    codigo          recomendacao_numero  assinatura encaminhamento    feedback  \
# 0   45331       A-582/CENIPA/2014 - 01  2016-07-29     2016-08-25  2016-12-20
# 1   45331       A-582/CENIPA/2014 - 02  2016-07-29     2016-08-25  2016-12-20
# 3   45392  A-032/CENIPA/2014 - RSV 001  2014-04-07     2015-04-14  2015-08-21
# 4   45392  A-032/CENIPA/2014 - RSV 002  2014-04-07     2015-04-14  2015-08-17
# 5   45397      IG-536/CENIPA/2014 - 01  2016-04-15     2016-05-17  2017-02-21
#
#                                recomendacao_conteudo  \
# 0  Atuar junto às empresas que operam segundo o R...
# 1  Atuar junto à Administração do Aeroporto Inter...
# 3  Divulgar aos operadores de helicópteros vincul...
# 4  Tendo em vista os fatos levantados nesta inves...
# 5  Certificar-se que a IS n° 00-002B, no capítulo...
#
#              recomendacao_status sigla          recomendacao_destinatario
# 0                       CUMPRIDA  ANAC  AGÊNCIA NACIONAL DE AVIAÇÃO CIVIL
# ...

# %%
anac.shape
# Out:
# (1237, 9)

# %%
df.groupby('recomendacao_status')['sigla'].nunique()
# Out:
# recomendacao_status
# ***                               5
# AGUARDANDO RESPOSTA               9
# CUMPRIDA                         12
# CUMPRIDA DE FORMA ALTERNATIVA     2
# NÃO CUMPRIDA                      1
# Name: sigla, dtype: int64
